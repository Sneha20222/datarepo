# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SNEHA PRAKASH TAMARALLI**
#
#
# Current Occupation : Sr.Automation Engineer

# %% [markdown]
# _I am interested in data science because i like to engineer the data and get something out of it_.

# %% [markdown]
# ### I have created a variable x and y and assigned value , adding those values and printing it

# %%
x = 5
y = 5
z = x+y

print(z)

# %% [markdown]
# * This is bulleted line
# ~~This line is striked~~
# [ link for the google](https://www.google.com)
